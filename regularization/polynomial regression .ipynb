# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random data points
np.random.seed(0)
X = np.linspace(-5, 5, 100)
y = 2*X + 3 + np.random.normal(0, 5, 100)

# %%
X = np.linspace(-5, 5, 100)
X
# Out:
# array([-5.        , -4.8989899 , -4.7979798 , -4.6969697 , -4.5959596 ,
#        -4.49494949, -4.39393939, -4.29292929, -4.19191919, -4.09090909,
#        -3.98989899, -3.88888889, -3.78787879, -3.68686869, -3.58585859,
#        -3.48484848, -3.38383838, -3.28282828, -3.18181818, -3.08080808,
#        -2.97979798, -2.87878788, -2.77777778, -2.67676768, -2.57575758,
#        -2.47474747, -2.37373737, -2.27272727, -2.17171717, -2.07070707,
#        -1.96969697, -1.86868687, -1.76767677, -1.66666667, -1.56565657,
#        -1.46464646, -1.36363636, -1.26262626, -1.16161616, -1.06060606,
#        -0.95959596, -0.85858586, -0.75757576, -0.65656566, -0.55555556,
#        -0.45454545, -0.35353535, -0.25252525, -0.15151515, -0.05050505,
#         0.05050505,  0.15151515,  0.25252525,  0.35353535,  0.45454545,
#         0.55555556,  0.65656566,  0.75757576,  0.85858586,  0.95959596,
#         1.06060606,  1.16161616,  1.26262626,  1.36363636,  1.46464646,
#         1.56565657,  1.66666667,  1.76767677,  1.86868687,  1.96969697,
#         2.07070707,  2.17171717,  2.27272727,  2.37373737,  2.47474747,
#         2.57575758,  2.67676768,  2.77777778,  2.87878788,  2.97979798,
#         3.08080808,  3.18181818,  3.28282828,  3.38383838,  3.48484848,
#         3.58585859,  3.68686869,  3.78787879,  3.88888889,  3.98989899,
#         4.09090909,  4.19191919,  4.29292929,  4.39393939,  4.49494949,
#         4.5959596 ,  4.6969697 ,  4.7979798 ,  4.8989899 ,  5.        ])

# %%
y = 2 * X + 3 + np.random.normal(0, 5, 100)
y
# Out:
# array([  2.41575349, -13.5367751 , -12.94838459,  -1.54695585,
#        -12.05753622,   3.72820694,  -7.85597369,  -9.32313264,
#          4.23087175,   2.22075578,   4.35799682,  -0.24755449,
#         -8.881886  ,   5.17658739,  -5.51173403,   0.04258501,
#          0.96858307,  -4.34070703,  -0.29323951,   1.4494172 ,
#         -1.0774683 ,  -8.25457971,  -1.06436468,   4.27839413,
#         -5.62435445,  -2.69766765,  -3.92324251,   7.7008641 ,
#          2.01803944,   0.89589504,  -4.78897431,   1.95887222,
#         -3.90701684,  -0.17418054,  -3.31054352,   3.45287355,
#          3.15568136,  -0.5667463 ,   2.65680124,  -4.58651966,
#         -6.37547988,   3.47978679,   2.31821596,   4.86202587,
#         13.80461276,   6.81330653,  -2.27118183,   8.08003094,
#         -3.88256736,   0.59106687,   2.75980207,  11.86974391,
#         -0.21872361,  -0.42512199,   3.41682829,   0.79371968,
#          9.94631092,  -0.88450603,  -1.02017154,   2.7300917 ,
#          2.63104987,  14.97089259,  10.27235656,   6.16502893,
#         -0.19788466,  10.35312801,   1.3322566 ,  -1.18850195,
#         12.6775227 ,   8.524107  ,  11.74570826,   8.93707261,
#         11.8296076 ,   4.49234678,   2.77828074,  11.55948774,
#          4.33648703,   5.10780667,   6.47991324,   9.04699175,
#          7.39164661,   2.4888799 ,   6.34756455,  -1.34933899,
#         13.09585422,   2.16142889,   4.85182068,  10.83658297,
#          7.0799628 ,  18.69487096,   4.71753363,  12.71909273,
#         11.38944449,   5.9474113 ,  14.60628229,  11.33418754,
#         16.25289215,  16.71348037,  23.61415954,  19.68263975])

# %%
from sklearn.linear_model import LinearRegression

# Fit linear regression
linear_reg = LinearRegression()
linear_reg.fit(X.reshape(-1, 1), y)

# Predict using linear regression
y_linear_pred = linear_reg.predict(X.reshape(-1, 1))

# Plot the data and linear regression line
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, y_linear_pred, color='red', label='Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# Transform features to polynomial degree 2
poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X.reshape(-1, 1))

# Fit polynomial regression
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y)

# Predict using polynomial regression
y_poly_pred = poly_reg.predict(X_poly)

# Plot the data and polynomial regression curve
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, y_poly_pred, color='green', label='Polynomial Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Polynomial Regression (Degree 2)')
plt.legend()
plt.show()

# %%
# Transform features to polynomial degree 2
poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X.reshape(-1, 1))

print(X_poly)
# Out:
# [ 1. -5. 25.]

# %%
# Fit polynomial regression
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y)

# Predict using polynomial regression
y_poly_pred = poly_reg.predict(X_poly)
y_poly_pred[0]
# Out:
# -1.6845802726016168

# %%
# Fit linear regression
linear_reg = LinearRegression()
linear_reg.fit(X.reshape(-1, 1), y)

# Predict using linear regression
y_linear_pred = linear_reg.predict(X.reshape(-1, 1))
y_linear_pred[0]
# Out:
# -5.957642760788968

# %%
from sklearn.metrics import r2_score

r2_score (y_poly_pred , y)
# Out:
# 0.16555387167167268

# %%
r2_score(y_linear_pred , y)
# Out:
# 0.09973097918321483

# %%
3
